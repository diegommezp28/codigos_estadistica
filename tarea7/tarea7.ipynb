# %%
from scipy.stats import binom
import numpy as np
import pandas as np

# %%
all_probs = []

for i in range(20, 60):
    prob = binom.ppf(0.1, i, 1/2)
    print(f'n = {i}. Prob para: p={1/2} = {prob} -- {binom.cdf(prob, i, 1/2)} -- {binom.cdf(prob, i, 1/3)}')
# Out:
# n = 20. Prob para: p=0.5 = 7.0 -- 0.13158798217773435 -- 0.661471482819107
# n = 21. Prob para: p=0.5 = 8.0 -- 0.19165515899658198 -- 0.7601245798965593
# n = 22. Prob para: p=0.5 = 8.0 -- 0.1431393623352051 -- 0.7070036814702387
# n = 23. Prob para: p=0.5 = 8.0 -- 0.10501980781555172 -- 0.6513532164521887
# n = 24. Prob para: p=0.5 = 9.0 -- 0.1537281274795532 -- 0.746165119816274
# n = 25. Prob para: p=0.5 = 9.0 -- 0.11476147174835194 -- 0.6955987713554286
# n = 26. Prob para: p=0.5 = 10.0 -- 0.16346979141235352 -- 0.7798760187901709
# n = 27. Prob para: p=0.5 = 10.0 -- 0.12389428168535242 -- 0.734225843096352
# n = 28. Prob para: p=0.5 = 11.0 -- 0.17246422544121742 -- 0.8089261305953285
# n = 29. Prob para: p=0.5 = 11.0 -- 0.132465448230505 -- 0.7679142080468707
# n = 30. Prob para: p=0.5 = 11.0 -- 0.10024421103298661 -- 0.7238643653096386
# n = 31. Prob para: p=0.5 = 12.0 -- 0.14052075752988463 -- 0.7972807698716923
# ...

# %%
print(41 * 0.4)
print(f'n = {41}. Prob para: p={1/2}  -- {binom.cdf(16.4, 41, 1/2)} -- {binom.cdf(16.4, 41, 1/3)}')
# Out:
# 16.400000000000002
# n = 41. Prob para: p=0.5  -- 0.10551179880440041 -- 0.8266628330399507
